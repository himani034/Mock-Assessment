# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV
df = pd.read_csv("student.csv")

# Clean columns (important)
df.columns = df.columns.str.strip().str.lower()

# 🔹 BAR CHART → Average score by subject
avg_scores = df.groupby("subject")["score"].mean()

plt.figure()
avg_scores.plot(kind='bar')
plt.title("Average Score by Subject")
plt.xlabel("Subject")
plt.ylabel("Average Score")
plt.show()

# 🔹 LINE CHART → Scores of students
plt.figure()
plt.plot(df["name"], df["score"], marker='o')
plt.title("Student Scores")
plt.xlabel("Students")
plt.ylabel("Score")
plt.show()

# %%
if 30 out of 100 students passed, what is probability?
P = 30 / 100 = 0.3
he probability of a student passing is 0.3 (or 30%).
