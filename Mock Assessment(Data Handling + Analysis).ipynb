# %%
import pandas as pd

df = pd.read_csv("student.csv")
print("Full Data:\n", df)
# Out:
# Full Data:
#       name  subject  score
# 0  Himani     Math     85
# 1   Rahul     Math     78
# 2    Amit  Science     90
# 3    Neha  Science     88
# 4    Riya     Math     92
# 5   Karan  English     75
# 6  Anjali  English     82
# 7   Vikas  Science     95

# %%
#Filtering
math_students = df[df["subject"] == "Math"]
print("\nMath Students:\n", math_students)
# Out:
# Math Students:
#       name subject  score
# 0  Himani    Math     85
# 1   Rahul    Math     78
# 4    Riya    Math     92
